# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px;">
#     <h1 style="color:#4CAF50; font-family: 'Lucida Console', Courier, monospace;">🔍 Exploratory Data Analysis (EDA)</h1>
#     <hr>
#     <p style="text-indent:2em; font-family: Arial;">
#         EDA is a critical step in the data science workflow. It helps us to understand the nature of the data, identify patterns, spot anomalies, and form hypotheses. Below, I'll conduct an EDA project using the provided <code>star_wars.csv</code> dataset.
#     </p>
#     <hr>
#     <h2 style="color:#FFA500; font-family: Arial;">📑 Project Structure</h2>
#     <ol style="font-family: Arial;">
#         <li><strong>Introduction</strong></li>
#         <li><strong>Data Loading and Initial Exploration</strong></li>
#         <li><strong>Data Cleaning</strong></li>
#         <li><strong>Exploratory Data Analysis</strong>
#             <ul>
#                 <li>Uncover patterns and insights through descriptive statistics and visualizations</li>
#                 <li>Univariate Analysis</li>
#                 <li>Bivariate Analysis</li>
#                 <li>Multivariate Analysis</li>
#             </ul>
#         </li>
#         <li><strong>Insights and Conclusions</strong>
#             <ul>
#                 <li>Summary and potential next steps</li>
#             </ul>
#         </li>
#     </ol>
#     <hr>
#     <p style="font-family: Arial; text-align:center;">
#         <strong>Let's get started!</strong>
#     </p>
# </div>

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <h2 style="color:#4CAF50; font-family: 'Lucida Console', Courier, monospace;">📚 1. Introduction</h2>
#     <hr>
#     <p style="text-indent:2em; font-family: Arial;">
#         The dataset appears to be related to <strong>Star Wars</strong>, a popular franchise. The goal of this EDA is to uncover insights and patterns that may be of interest. This could be useful for anyone interested in understanding the dataset more deeply, whether for academic, business, or personal reasons.
#     </p>
# </div>

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <h2 style="color:#4CAF50; font-family: 'Lucida Console', Courier, monospace;">🔎 2. Data Loading and Initial Exploration</h2>
#     <hr>
#     <p style="text-indent:2em; font-family: Arial;">
#         First, we will load the dataset and take a look at the first few rows to understand its structure.
#     </p>
#     <p style="text-indent:2em; font-family: Arial;">
#         The dataset contains a variety of questions related to the <strong>Star Wars</strong> franchise, including which movies the respondents have seen, their opinions on characters, and demographic information like age, gender, and location.
#     </p>
# </div>

# %%
import pandas as pd

# Load the dataset
file_path = 'star_wars.csv'
df = pd.read_csv(file_path)

# Show the first few rows of the dataframe
df.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <p style="text-indent:2em; font-family: Arial;">
#         It seems that the dataset contains multiple columns related to <strong>Star Wars</strong> films, demographics, and opinions.
#     </p>
#     <hr>
#     <p style="font-family: Arial; text-align:center;">
#         <strong>Let's move on to the next steps of our analysis.</strong>
#     </p>
# </div>

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <h2 style="color:#4CAF50; font-family: 'Lucida Console', Courier, monospace;">🧹 3. Data Cleaning</h2>
#     <hr>
#     <p style="text-indent:2em; font-family: Arial;">
#         Before diving into the EDA, it's crucial to clean the data. Some of the tasks to be performed include:
#     </p>
#     <ol style="font-family: Arial;">
#         <li>Removing rows with missing or irrelevant <code>RespondentID</code>.</li>
#         <li>Renaming columns for easier reference.</li>
#         <li>Handling missing values.</li>
#     </ol>
#     <hr>
#     <h3 style="color:#4CAF50; font-family: Arial;">🔍 3.1 Removing Rows with Missing or Irrelevant <code>RespondentID</code></h3>
#     <p style="text-indent:2em; font-family: Arial;">
#         Let's start by removing rows where <code>RespondentID</code> is missing or irrelevant.
#     </p>
#     <p style="text-indent:2em; font-family: Arial;">
#         It seems that the output is getting truncated again, which is limiting our ability to view the entire dataset structure. However, the first step of data cleaning—removing rows with missing <code>RespondentID</code>—has been completed.
#     </p>
# </div>

# %%
# Remove rows where RespondentID is NaN
df = df[df['RespondentID'].notna()]

# Show the first few rows after removing missing RespondentID
df.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
# 5                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <h3 style="color:#4CAF50; font-family: Arial;">🛠️ 3.2 Handle Other Missing Values and Data Types</h3>
#     <p style="text-indent:2em; font-family: Arial;">
#         Now, let's rename some columns for easier reference and understanding. Specifically, we'll focus on renaming the columns related to which <strong>Star Wars</strong> films the respondents have seen.
#     </p>
#     <p style="text-indent:2em; font-family: Arial;">
#         Great, we've successfully renamed the columns related to which <strong>Star Wars</strong> films the respondents have seen. This will make it easier to understand and analyze the data.
#     </p>
# </div>

# %%
# Check for missing values in each column
missing_values = df.isna().sum()

# Check the data types of each column
data_types = df.dtypes

missing_values, data_types
# Out:
# (RespondentID                                                                                                                                       0
#  Have you seen any of the 6 films in the Star Wars franchise?                                                                                       0
#  Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            350
#  Which of the following Star Wars films have you seen? Please select all that apply.                                                              513
#  Unnamed: 4                                                                                                                                       615
#  Unnamed: 5                                                                                                                                       636
# ...

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <ul style="font-family: Arial;">
#         <li>There are missing values in multiple columns, including the one asking if respondents consider themselves fans of the <strong>Star Wars</strong> franchise, which movies they've seen, and so on.</li>
#         <li>All columns are of the object data type, which suggests that we might need to convert some of them to more appropriate types for analysis.</li>
#     </ul>
#     <ul style="font-family: Arial;">
#         <li>For columns asking whether the respondent has seen a movie or is a fan, we'll replace missing values with 'Unknown'.</li>
#         <li>For ranking and multiple-choice questions, we'll leave the NaN values as they are, assuming they mean the question was not answered.</li>
#     </ul>
#     <hr>
#     <h3 style="color:#4CAF50; font-family: Arial;">🔄 3.3 Data Cleaning Steps</h3>
#     <p style="text-indent:2em; font-family: Arial;">
#         We'll convert the entries in the newly renamed <code>Seen_X</code> columns to Boolean values to indicate whether a respondent has seen a particular <strong>Star Wars</strong> movie. This will also handle the missing values by converting them to <code>False</code>.
#     </p>
#     <p style="text-indent:2em; font-family: Arial;">
#         The columns related to <strong>Star Wars</strong> films the respondents have seen are now in Boolean format, making them easier to analyze.
#     </p>
#     <hr>
#     <p style="font-family: Arial; text-align:center;">
#         <strong>With the data cleaning steps completed, we can move on to the Exploratory Data Analysis (EDA) part.</strong>
#     </p>
# </div>

# %%
# Replace missing values in specific columns with 'Unknown'
columns_to_fill = [
    'Have you seen any of the 6 films in the Star Wars franchise?',
    'Do you consider yourself to be a fan of the Star Wars film franchise?',
    'Are you familiar with the Expanded Universe?',
    'Do you consider yourself to be a fan of the Expanded Universe?æ',
    'Do you consider yourself to be a fan of the Star Trek franchise?'
]

df[columns_to_fill] = df[columns_to_fill].fillna('Unknown')

# Check if the replacement worked
df[columns_to_fill].isna().sum()
# Out:
# Have you seen any of the 6 films in the Star Wars franchise?             0
# Do you consider yourself to be a fan of the Star Wars film franchise?    0
# Are you familiar with the Expanded Universe?                             0
# Do you consider yourself to be a fan of the Expanded Universe?æ         0
# Do you consider yourself to be a fan of the Star Trek franchise?         0
# dtype: int64

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <p style="text-indent:2em; font-family: Arial;">
#         Great, the missing values in the specified columns have been successfully replaced with 'Unknown'.
#     </p>
#     <hr>
#     <h2 style="color:#4CAF50; font-family: 'Lucida Console', Courier, monospace;">📊 4. Exploratory Data Analysis (EDA)</h2>
#     <p style="text-indent:2em; font-family: Arial;">
#         In this section, we will dive into the data to uncover patterns, relationships, and insights. We'll focus on:
#     </p>
#     <ol style="font-family: Arial;">
#         <li><strong>Explore the demographics of the respondents.</strong></li>
#         <li><strong>Analyze the popularity of the Star Wars movies.</strong></li>
#         <li><strong>Investigate the fan base.</strong></li>
#     </ol>
#     <p style="font-family: Arial;">
#         The following should be added later:
#     </p>
#     <ol style="font-family: Arial;">
#         <li><strong>Univariate Analysis</strong>: Analyzing single variables.</li>
#         <li><strong>Bivariate Analysis</strong>: Investigating relationships between two variables.</li>
#         <li><strong>Multivariate Analysis</strong>: Exploring interactions among multiple variables.</li>
#     </ol>
#     <hr>
#     <h3 style="color:#4CAF50; font-family: Arial;">👥 Explore the Demographics of the Respondents</h3>
#     <p style="text-indent:2em; font-family: Arial;">
#         Let's start by exploring the age, gender, and location of the respondents. We'll visualize these demographics to better understand the composition of our dataset.
#     </p>
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plots
sns.set(style="whitegrid")

# Create subplots for Age, Gender, and Location
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))

# Plot Age distribution
sns.countplot(data=df, x='Age', ax=axes[0])
axes[0].set_title('Age Distribution')
axes[0].set_xlabel('Age Groups')
axes[0].set_ylabel('Count')

# Plot Gender distribution
sns.countplot(data=df, x='Gender', ax=axes[1])
axes[1].set_title('Gender Distribution')
axes[1].set_xlabel('Gender')
axes[1].set_ylabel('Count')

# Plot Location distribution
sns.countplot(data=df, y='Location (Census Region)', ax=axes[2])
axes[2].set_title('Location Distribution')
axes[2].set_xlabel('Count')
axes[2].set_ylabel('Location (Census Region)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <p style="text-indent:2em; font-family: Arial;">
#         Here are some insights from the demographic distributions:
#     </p>
#     <ul style="font-family: Arial;">
#         <li><strong>Age Distribution:</strong> The age group "45-60" has the highest number of respondents, followed by the "30-44" age group. The "18-29" and "60+" age groups are less represented in the dataset.</li>
#         <li><strong>Gender Distribution:</strong> The dataset has more male respondents compared to female respondents.</li>
#         <li><strong>Location Distribution:</strong> Respondents are primarily from the "East North Central" and "Pacific" regions, with other regions being less represented.</li>
#     </ul>
#     <hr>
#     <h3 style="color:#4CAF50; font-family: Arial;">🎬 4.2 Analyze the Popularity of the Star Wars Movies</h3>
#     <p style="text-indent:2em; font-family: Arial;">
#         Next, let's find out which Star Wars movies are the most and least popular among the respondents. We'll look at the number of people who have watched each movie and their rankings.
#     </p>
# </div>

# %%
# Columns related to which movies the respondents have seen
movies_seen_columns = df.columns[3:9]

# Rename these columns for easier analysis
new_column_names = [
    'Seen Episode I',
    'Seen Episode II',
    'Seen Episode III',
    'Seen Episode IV',
    'Seen Episode V',
    'Seen Episode VI'
]

# Create a mapping dictionary and rename the columns
rename_dict = {old: new for old, new in zip(movies_seen_columns, new_column_names)}
df.rename(columns=rename_dict, inplace=True)

# Convert the values to 'Yes' if the respondent has seen the movie, and 'No' otherwise
for col in new_column_names:
    df[col] = df[col].apply(lambda x: 'Yes' if pd.notna(x) else 'No')

# Count the number of 'Yes' for each movie
movie_popularity = df[new_column_names].apply(lambda x: x == 'Yes').sum()

# Plot the popularity of each movie
plt.figure(figsize=(12, 6))
sns.barplot(x=movie_popularity.index, y=movie_popularity.values)
plt.title('Popularity of Star Wars Movies')
plt.xlabel('Movies')
plt.ylabel('Number of Views')
plt.show()

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <p style="text-indent:2em; font-family: Arial;">
#         The bar chart indicates the number of respondents who have seen each Star Wars episode:
#     </p>
#     <ul style="font-family: Arial;">
#         <li><strong>Seen Episode V:</strong> This appears to be the most popular movie, with the highest number of views among the respondents.</li>
#         <li><strong>Seen Episode III:</strong> This movie has the least number of views, making it the least popular among the respondents.</li>
#     </ul>
#     <hr>
#     <h3 style="color:#4CAF50; font-family: Arial;">👥 4.3 Investigate the Fan Base</h3>
#     <p style="text-indent:2em; font-family: Arial;">
#         We'll now explore the fan base of the Star Wars franchise, focusing on the following:
#     </p>
#     <ul style="font-family: Arial;">
#         <li><strong>The proportion of respondents who consider themselves fans.</strong></li>
#         <li><strong>How this fan base varies across different age groups.</strong></li>
#     </ul>
#     <p style="text-indent:2em; font-family: Arial;">
#         Let's start by looking at the overall proportion of fans.
#     </p>
# </div>

# %%
# Plot the proportion of respondents who consider themselves fans of Star Wars
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Do you consider yourself to be a fan of the Star Wars film franchise?')
plt.title('Proportion of Star Wars Fans')
plt.xlabel('Are you a fan?')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:20px; border-radius:10px; margin-bottom: 20px;">
#     <p style="text-indent:2em; font-family: Arial;">
#         The bar chart shows the distribution of respondents based on whether they consider themselves fans of the Star Wars franchise:
#     </p>
#     <ul style="font-family: Arial;">
#         <li><strong>A significant number of respondents consider themselves fans.</strong></li>
#         <li><strong>A smaller, but still notable, number of respondents do not consider themselves fans.</strong></li>
#         <li><strong>There's also a segment that chose 'Unknown', which likely includes those who didn't answer this question.</strong></li>
#     </ul>
#     <p style="text-indent:2em; font-family: Arial;">
#         Now, let's see how the fan base varies across different age groups.
#     </p>
#     <hr>
#     <h3 style="color:#4CAF50; font-family: Arial;">📊 4.1 Univariate Analysis</h3>
#     <ul style="font-family: Arial;">
#         <li><strong>Distribution of respondents by gender</strong></li>
#         <li><strong>Distribution of respondents by age</strong></li>
#         <li><strong>Distribution of respondents by household income</strong></li>
#     </ul>
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Remove the first row which contains 'Response' as it seems to be metadata
df = df.iloc[1:]

# Convert some of the columns to appropriate types for analysis
df['RespondentID'] = df['RespondentID'].astype('str')

# Dropping rows where gender or age is NaN for the purpose of visualization
df = df.dropna(subset=['Gender', 'Age'])

# Set up the matplotlib figure
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Univariate Analysis
# 1. Distribution of respondents by Gender
sns.countplot(x='Gender', data=df, ax=axes[0])
axes[0].set_title('Distribution of Respondents by Gender')

# 2. Distribution of respondents by Age
sns.countplot(x='Age', data=df, ax=axes[1], order=df['Age'].value_counts().index)
axes[1].set_title('Distribution of Respondents by Age')
axes[1].tick_params(axis='x', rotation=45)

# 3. Distribution of respondents by Household Income
sns.countplot(x='Household Income', data=df, ax=axes[2], order=df['Household Income'].value_counts().index)
axes[2].set_title('Distribution of Respondents by Household Income')
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📊 <strong>Distribution of Respondents by Gender</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">The majority of respondents are male. This could be indicative of the Star Wars franchise's primary audience, or it might be related to the sample of people who took this survey.</p>
#
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📊 <strong>Distribution of Respondents by Age</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">The age group most represented in the dataset is "45-60", followed by "30-44". The least represented age group is "60+". This could provide insights into which age groups are most interested in the Star Wars franchise.</p>
#
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📊 <strong>Distribution of Respondents by Household Income</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">Most respondents did not provide information about their household income, as indicated by the large number of missing values. Among those who did, the most common income range is "$50,000 - $99,999".</p>
#
# <hr>
#
# <h3 style="color: #34495E; font-family: Arial, sans-serif;">📈 <strong>4.2 Bivariate Analysis</strong></h3>
# <ul style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#     <li>Correlation between age and household income</li>
#     <li>Gender vs. Star Wars film fandom</li>
#     <li>Age vs. Star Wars film fandom</li>
# </ul>

# %%
# Bivariate Analysis
# Prepare the data by replacing string-based categorical values with numerical ones for certain columns
# This is done for easier correlation analysis

# Mapping age groups to numerical values
age_mapping = {
    '18-29': 1,
    '30-44': 2,
    '45-60': 3,
    '> 60': 4
}
df['Age_numeric'] = df['Age'].map(age_mapping)

# Mapping household income to numerical values
income_mapping = {
    '$0 - $24,999': 1,
    '$25,000 - $49,999': 2,
    '$50,000 - $99,999': 3,
    '$100,000 - $149,999': 4,
    '$150,000+': 5
}
df['Income_numeric'] = df['Household Income'].map(income_mapping)

# Set up the matplotlib figure
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# 1. Correlation between Age and Household Income
sns.scatterplot(x='Age_numeric', y='Income_numeric', data=df, ax=axes[0])
axes[0].set_title('Correlation between Age and Household Income')
axes[0].set_xlabel('Age Group (Numerically Mapped)')
axes[0].set_ylabel('Household Income (Numerically Mapped)')

# 2. Gender vs Star Wars film fandom
sns.countplot(x='Gender', hue='Do you consider yourself to be a fan of the Star Wars film franchise?', data=df, ax=axes[1])
axes[1].set_title('Gender vs Star Wars Film Fandom')

# 3. Age vs Star Wars film fandom
sns.countplot(x='Age', hue='Do you consider yourself to be a fan of the Star Wars film franchise?', data=df, ax=axes[2])
axes[2].set_title('Age vs Star Wars Film Fandom')
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📈 <strong>Correlation between Age and Household Income</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">At first glance, there doesn't seem to be a strong correlation between age and household income based on the scatter plot. The data points are spread across the chart without any clear trend. Note that the age and income groups were numerically mapped for easier visualization.</p>
#
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📈 <strong>Gender vs Star Wars Film Fandom</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">Among males and females, the majority consider themselves to be fans of the Star Wars franchise. However, the number of male fans appears to be significantly higher than female fans.</p>
#
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📈 <strong>Age vs Star Wars Film Fandom</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">Across various age groups, the majority consider themselves fans of the Star Wars franchise. The age group "45-60" has the highest number of fans, followed by "30-44".</p>
#
# <hr>
#
# <h3 style="color: #34495E; font-family: Arial, sans-serif;">📊 <strong>4.3 Multivariate Analysis</strong></h3>
# <ul style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#     <li>Pairplot or heatmap to show correlations between multiple variables, if applicable</li>
# </ul>

# %%
# Multivariate Analysis

# Select only the columns that are relevant for the multivariate analysis
# For demonstration purposes, I've selected gender, age, household income, and fandom status
selected_columns = ['Gender', 'Age_numeric', 'Income_numeric', 'Do you consider yourself to be a fan of the Star Wars film franchise?']
df_selected = df[selected_columns].dropna()

# Map 'Yes' and 'No' in fandom status to 1 and 0 respectively for easier correlation analysis
df_selected['Fandom_numeric'] = df_selected['Do you consider yourself to be a fan of the Star Wars film franchise?'].map({'Yes': 1, 'No': 0})

# Map 'Male' and 'Female' in gender to 1 and 0 respectively for easier correlation analysis
df_selected['Gender_numeric'] = df_selected['Gender'].map({'Male': 1, 'Female': 0})

# Calculate the correlation matrix
correlation_matrix = df_selected[['Gender_numeric', 'Age_numeric', 'Income_numeric', 'Fandom_numeric']].corr()

# Draw the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix of Selected Variables")
plt.show()

# Pairplot to visualize relationships between numerical variables
sns.pairplot(df_selected, hue='Do you consider yourself to be a fan of the Star Wars film franchise?', diag_kind='kde')
plt.suptitle('Pairplot of Selected Variables', y=1.02)
plt.show()

# %% [markdown]
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📈 <strong>Correlation Matrix of Selected Variables</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">The correlation matrix shows that there is no strong correlation between the selected variables (Gender, Age, Household Income, and Star Wars Film Fandom). The highest correlation value is approximately 0.16, indicating a very weak correlation.</p>
#
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📈 <strong>Pairplot of Selected Variables</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#     The pairplot provides a visualization of the relationships between the selected numerical variables. Different colors represent whether the respondent is a fan of the Star Wars franchise or not. The KDE (Kernel Density Estimation) plots along the diagonal show the distribution of each variable. No clear patterns or trends are visible in the scatter plots, reinforcing the findings from the correlation matrix that there are no strong correlations between these variables.
# </p>
#
# <hr>
#
# <h2 style="color: #34495E; font-family: Arial, sans-serif;">📊 <strong>Section 5: Insights and Observations</strong></h2>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   After a comprehensive analysis comprising univariate, bivariate, and multivariate visualizations, the following insights and observations can be made:
# </p>
# <ol style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#     <li><strong>Demographics</strong>: The majority of respondents are male, falling within the "45-60" age group.</li>
#     <li><strong>Star Wars Fandom</strong>: The number of fans of the Star Wars franchise is significantly higher among males. The "45-60" age group has the highest representation among Star Wars fans, according to this dataset.</li>
#     <li><strong>Household Income</strong>: Most of the respondents chose not to disclose their household income. Among those who did, the majority fall within the "$50,000 - $99,999" range.</li>
#     <li><strong>Correlations</strong>: The correlation analysis didn't reveal any strong relationships between gender, age, household income, and Star Wars fandom. This might suggest that the fandom is diverse and not strictly dependent on these factors.</li>
#     <li><strong>Multivariate Analysis</strong>: The correlation matrix and pair plots further confirmed the lack of strong correlations between the selected variables.</li>
# </ol>
#
# <hr>
#
# <h2 style="color: #34495E; font-family: Arial, sans-serif;">📚 <strong>Section 6: Summary and Conclusions</strong></h2>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   The Exploratory Data Analysis provided valuable insights into the demographics and preferences of the respondents concerning the Star Wars franchise. While the dataset does not show strong correlations between the different variables, it does offer a snapshot of the diversity within the Star Wars fan community. Further research could involve more variables and could be aimed at understanding the reasons behind these preferences and demographics.
# </p>

# %% [markdown]
# <hr>
#
# <h2 style="color: #34495E; font-family: Arial, sans-serif;">🌍 <strong>Extra Analysis: Location-based Analysis</strong></h2>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📍 <strong>Distribution of Respondents by Location</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   The dataset shows that the majority of respondents are from the "East North Central" and "Pacific" regions. Other regions are less represented, which may indicate regional preferences or could be related to the sampling method.
# </p>
#
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📍 <strong>Correlation Between Location and Gender</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   The data indicates that the gender distribution is relatively uniform across all regions, suggesting that the Star Wars franchise has a wide-reaching fan base across both genders.
# </p>
#
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📍 <strong>Correlation Between Location and Age</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   Certain regions like the "Pacific" have a younger audience compared to regions like the "East North Central," where the age group "45-60" is more prevalent. This could offer further insights into regional preferences.
# </p>
#
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📍 <strong>Correlation Between Location and Star Wars Fandom</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   The level of fandom also varies by region, although the "Pacific" and "East North Central" regions have the highest number of self-proclaimed Star Wars fans. This could be an interesting avenue for further investigation.
# </p>
#
# <hr>

# %%
# First, let's visualize the distribution of respondents based on their 'Location (Census Region)'
plt.figure(figsize=(14, 7))
sns.countplot(y='Location (Census Region)', data=df, order=df['Location (Census Region)'].value_counts().index)
plt.title('Distribution of Respondents by Location (Census Region)')
plt.xlabel('Number of Respondents')
plt.ylabel('Census Region')
plt.show()

# %%
# Set up the matplotlib figure
fig, axes = plt.subplots(1, 3, figsize=(18, 8))

# 1. Correlation between Location and Gender
sns.countplot(y='Location (Census Region)', hue='Gender', data=df, ax=axes[0], order=df['Location (Census Region)'].value_counts().index)
axes[0].set_title('Location vs Gender')

# 2. Correlation between Location and Age
sns.countplot(y='Location (Census Region)', hue='Age', data=df, ax=axes[1], order=df['Location (Census Region)'].value_counts().index)
axes[1].set_title('Location vs Age')

# 3. Correlation between Location and Star Wars Fandom
sns.countplot(y='Location (Census Region)', hue='Do you consider yourself to be a fan of the Star Wars film franchise?', data=df, ax=axes[2], order=df['Location (Census Region)'].value_counts().index)
axes[2].set_title('Location vs Star Wars Fandom')

plt.tight_layout()
plt.show()

# %% [markdown]
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">🌎 <strong>Distribution of Respondents by Country (Simulated Data)</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   <ul>
#     <li>The map visualizes the number of respondents from different countries around the world. Darker shades represent a higher number of respondents.</li>
#     <li>Countries in lighter shades either had fewer respondents or were not represented in this simulated dataset.</li>
#   </ul>
# </p>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   <em>Please note that the data for countries other than the U.S. is simulated based on population estimates, as the original dataset was specific to the U.S.</em>
# </p>
#
# <hr>

# %%
import geopandas as gpd

# Load the world shapefile
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Preparing the data for merging with shapefile
# Since our dataset is U.S. specific, we will simulate data for other countries for demonstration purposes.
# In a real-world scenario, this data would come from your dataset.
world['Count'] = world['pop_est'] / 10000  # Simulating respondent count based on population

# Plotting
fig, ax = plt.subplots(1, figsize=(15, 10))
world.boundary.plot(ax=ax, linewidth=1)
world.plot(column='Count', ax=ax, legend=True, cmap='OrRd',
           legend_kwds={'label': "Number of Respondents by Country"},
           missing_kwds={'color': 'lightgrey'})

plt.title('Distribution of Respondents by Country (Simulated Data)')
plt.show()
# Out:
# /home/ehsan/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:48: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:
# /home/ehsan/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:48: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:

# %% [markdown]
# <hr>
#
# <h2 style="color: #34495E; font-family: Arial, sans-serif;">🔍 <strong>Extra Analysis: Advanced Techniques</strong></h2>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📊 <strong>Clustering to Identify Distinct Groups</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   In order to unravel the underlying structure of our dataset, we'll employ the K-means clustering technique. This is an unsupervised machine learning algorithm that could provide insights into the heterogeneity of the respondents.
# </p>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📊 <strong>Data Preprocessing for Clustering</strong></h3>
# <ol style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 40px;">
#   <li><strong>Select Relevant Variables:</strong> The first step involves picking a subset of variables that are likely to reveal distinct clusters. Given that K-means is sensitive to the scale of the variables, the selection should ideally involve numerical variables.</li>
#   <li><strong>Preprocess the Data:</strong> Before applying the K-means algorithm, we'll need to preprocess the data. This involves handling missing values, scaling the variables, and encoding categorical variables.</li>
#   <li><strong>Apply K-means and Visualize:</strong> After preprocessing, we'll apply the K-means algorithm to identify clusters. We'll then visualize these clusters to interpret their characteristics.</li>
# </ol>
#
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">Let's start by selecting and preprocessing the data.</p>
#
# <hr>

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# Selecting a subset of columns for clustering
selected_columns = ['Gender', 'Age', 'Household Income', 'Do you consider yourself to be a fan of the Star Wars film franchise?']
df_clustering = df[selected_columns].dropna()

# Encoding categorical variables
label_encoder = LabelEncoder()
for col in selected_columns:
    df_clustering[col] = label_encoder.fit_transform(df_clustering[col])

# Standardizing the features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_clustering)

# Applying PCA for dimensionality reduction
pca = PCA(n_components=2)
principal_components = pca.fit_transform(df_scaled)
principal_df = pd.DataFrame(data=principal_components, columns=['Principal Component 1', 'Principal Component 2'])

# Finding the optimal number of clusters using the elbow method
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method For Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# <hr>
#
# <h3 style="color: #2E86C1; font-family: Arial, sans-serif;">📈 <strong>Determining the Optimal Number of Clusters</strong></h3>
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   - The elbow method is commonly used to find the optimal number of clusters for K-means clustering. The point where the inertia starts to decrease at a slower rate ("the elbow") is generally considered the optimal number of clusters.
#   - In this case, the elbow appears to be around 2 or 3 clusters.
# </p>
#
# <p style="font-size: 16px; font-family: Arial, sans-serif; margin-left: 20px;">
#   Next, I'll proceed with applying K-means clustering using 3 clusters and then visualize these clusters in the 2D space formed by the first two principal components.
# </p>
#
# <hr>

# %%
#Dropping rows where gender or age is NaN for the purpose of visualization
df = df.dropna(subset=['Gender', 'Age'])

# Selecting a subset of columns for clustering
selected_columns = ['Gender', 'Age', 'Household Income', 'Do you consider yourself to be a fan of the Star Wars film franchise?']
df_clustering = df[selected_columns].dropna()

# Encoding categorical variables
label_encoder = LabelEncoder()
for col in selected_columns:
    df_clustering[col] = label_encoder.fit_transform(df_clustering[col])

# Standardizing the features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_clustering)

# Applying PCA for dimensionality reduction
pca = PCA(n_components=2)
principal_components = pca.fit_transform(df_scaled)
principal_df = pd.DataFrame(data=principal_components, columns=['Principal Component 1', 'Principal Component 2'])

# Applying K-means clustering with 3 clusters
kmeans = KMeans(n_clusters=3, random_state=0)
clusters = kmeans.fit_predict(df_scaled)

# Adding the cluster labels to the principal component dataframe
principal_df['Cluster'] = clusters

# Visualizing the clusters
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Principal Component 1', y='Principal Component 2', hue='Cluster', data=principal_df, palette='viridis')
plt.title('Clusters of Respondents')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
